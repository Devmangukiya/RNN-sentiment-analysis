# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\hp\Desktop\RNN\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### Sentences.
sent = ['the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'i am a good boy',
        'i am a good interview',
        'understand the meaning of words',
        'your videos are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'i am a good boy',
#  'i am a good interview',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size.

voc_size = 10000

# %%
## One Hot Representation

one_hot_repr = [one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[159, 9469, 8344, 7105],
#  [159, 9469, 8344, 3610],
#  [159, 308, 8344, 9168],
#  [5079, 8284, 5990, 2277, 7435],
#  [5079, 8284, 5990, 2277, 3738],
#  [4852, 159, 2476, 8344, 1392],
#  [51, 4584, 6207, 2277]]

# %%
## To see index of 'glass' in vocabulary.

one_hot('glass',voc_size)
# Out:
# [9469]

# %%
## Word Embedding Representation.

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import pandas  as pd
import numpy as np

# %%
sent_length = 8
embeded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embeded_docs)
# Out:
# [[   0    0    0    0  159 9469 8344 7105]
#  [   0    0    0    0  159 9469 8344 3610]
#  [   0    0    0    0  159  308 8344 9168]
#  [   0    0    0 5079 8284 5990 2277 7435]
#  [   0    0    0 5079 8284 5990 2277 3738]
#  [   0    0    0 4852  159 2476 8344 1392]
#  [   0    0    0    0   51 4584 6207 2277]]

# %%
## Feature representation..

dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\hp\Desktop\RNN\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\hp\Desktop\RNN\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embeded_docs)
# Out:
# 1/1 [==============================] - 1s 578ms/step
# array([[[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.02559054,  0.0010379 , -0.00203985, -0.00626668,
#           0.00358626,  0.035189  ,  0.04408845, -0.03850945,
#           0.0299433 , -0.02185397],
#         [ 0.02554836,  0.00157478,  0.01806417,  0.03977901,
#          -0.00447597,  0.03202567, -0.04774572, -0.02553369,
#          -0.01068477, -0.04256615],
#         [-0.03677461, -0.03337146,  0.01292341,  0.04561241,
#           0.04770649, -0.01844116,  0.04075236,  0.04460216,
#          -0.04281138,  0.00382092],
#         [-0.01407301,  0.04640453, -0.00600319, -0.01394832,
#           0.00753864, -0.03034344, -0.00590347,  0.0126933 ,
#           0.04518792,  0.02605638]],
#
#        [[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.02559054,  0.0010379 , -0.00203985, -0.00626668,
#           0.00358626,  0.035189  ,  0.04408845, -0.03850945,
#           0.0299433 , -0.02185397],
#         [ 0.02554836,  0.00157478,  0.01806417,  0.03977901,
#          -0.00447597,  0.03202567, -0.04774572, -0.02553369,
#          -0.01068477, -0.04256615],
#         [-0.03677461, -0.03337146,  0.01292341,  0.04561241,
#           0.04770649, -0.01844116,  0.04075236,  0.04460216,
#          -0.04281138,  0.00382092],
#         [ 0.0375508 ,  0.0221752 , -0.03018705,  0.03142648,
#           0.01303921,  0.00583525, -0.01183748,  0.01736971,
#           0.04479362, -0.00765123]],
#
#        [[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.02559054,  0.0010379 , -0.00203985, -0.00626668,
#           0.00358626,  0.035189  ,  0.04408845, -0.03850945,
#           0.0299433 , -0.02185397],
#         [-0.04108395, -0.04597927,  0.03596978,  0.02091236,
#           0.02567491, -0.0016709 ,  0.02404842,  0.02459929,
#           0.02457856, -0.01701241],
#         [-0.03677461, -0.03337146,  0.01292341,  0.04561241,
#           0.04770649, -0.01844116,  0.04075236,  0.04460216,
#          -0.04281138,  0.00382092],
#         [ 0.0050981 ,  0.0165784 , -0.02553217, -0.03254367,
#          -0.03537905,  0.02625456, -0.01471835, -0.0382086 ,
#          -0.00492462, -0.03272277]],
#
#        [[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.01892188, -0.00716599,  0.00470696,  0.01043627,
#          -0.04703934, -0.04526088, -0.02644483,  0.03579232,
#           0.04633938,  0.00223944],
#         [-0.00881713, -0.0129781 , -0.01235276,  0.00157411,
#          -0.03324174, -0.01487576, -0.01737029, -0.02982218,
#          -0.01573499, -0.03913222],
#         [-0.01215085,  0.00723089, -0.01374529,  0.04094687,
#          -0.02591806, -0.02264038, -0.03925922, -0.04122738,
#           0.01506961,  0.02745826],
#         [ 0.00483419,  0.04710375,  0.04496715,  0.00695731,
#           0.02504374, -0.00414506,  0.03427548,  0.03791611,
#           0.04629601,  0.02795783],
#         [-0.01675191,  0.02701283,  0.01636311, -0.01113408,
#          -0.02267026,  0.02042456, -0.02094129, -0.0384702 ,
#           0.04262478,  0.01040733]],
#
#        [[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.01892188, -0.00716599,  0.00470696,  0.01043627,
#          -0.04703934, -0.04526088, -0.02644483,  0.03579232,
#           0.04633938,  0.00223944],
#         [-0.00881713, -0.0129781 , -0.01235276,  0.00157411,
#          -0.03324174, -0.01487576, -0.01737029, -0.02982218,
#          -0.01573499, -0.03913222],
#         [-0.01215085,  0.00723089, -0.01374529,  0.04094687,
#          -0.02591806, -0.02264038, -0.03925922, -0.04122738,
#           0.01506961,  0.02745826],
#         [ 0.00483419,  0.04710375,  0.04496715,  0.00695731,
#           0.02504374, -0.00414506,  0.03427548,  0.03791611,
#           0.04629601,  0.02795783],
#         [ 0.0405626 ,  0.01018719,  0.01306159,  0.02868799,
#           0.0325986 ,  0.02876474, -0.02152683,  0.04572303,
#           0.03016802,  0.02081252]],
#
#        [[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [ 0.02956552, -0.01220465, -0.03331625,  0.02453175,
#          -0.0112757 , -0.04906342, -0.04400782,  0.04326372,
#           0.01953615,  0.00098388],
#         [-0.02559054,  0.0010379 , -0.00203985, -0.00626668,
#           0.00358626,  0.035189  ,  0.04408845, -0.03850945,
#           0.0299433 , -0.02185397],
#         [ 0.04808846,  0.01648584,  0.04293779, -0.03689082,
#          -0.0341754 , -0.04609077, -0.0484044 , -0.04849396,
#          -0.04807889, -0.04996573],
#         [-0.03677461, -0.03337146,  0.01292341,  0.04561241,
#           0.04770649, -0.01844116,  0.04075236,  0.04460216,
#          -0.04281138,  0.00382092],
#         [ 0.02493943,  0.01247118, -0.0096578 ,  0.0441047 ,
#           0.0432033 , -0.01514126, -0.00754689,  0.04594985,
#          -0.04808419,  0.04211659]],
#
#        [[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,
#           0.0082067 ,  0.02803427,  0.00564752, -0.02310201,
#          -0.0025723 , -0.03468137],
#         [-0.03717019,  0.02299387, -0.02320976,  0.02224144,
#          -0.02859349,  0.02268015,  0.00430015, -0.02525698,
#           0.03376788, -0.02975966],
#         [ 0.01123194, -0.02341636, -0.02370203,  0.02521561,
#           0.02191276,  0.04695391,  0.00055382, -0.03332784,
#           0.04186274,  0.00026489],
#         [-0.0161112 , -0.03753532, -0.0428005 , -0.02596337,
#          -0.03449274, -0.0278629 , -0.03499175, -0.0376283 ,
#          -0.02742552, -0.01067168],
#         [ 0.00483419,  0.04710375,  0.04496715,  0.00695731,
#           0.02504374, -0.00414506,  0.03427548,  0.03791611,
#           0.04629601,  0.02795783]]], dtype=float32)

# %%
embeded_docs[0]
# Out:
# array([   0,    0,    0,    0,  159, 9469, 8344, 7105])

# %%
model.predict(embeded_docs[0])
# Out:
# 1/1 [==============================] - 0s 107ms/step
# array([[-0.04710129,  0.03620065, -0.0278469 , -0.04429885,  0.0082067 ,
#          0.02803427,  0.00564752, -0.02310201, -0.0025723 , -0.03468137],
#        [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,  0.0082067 ,
#          0.02803427,  0.00564752, -0.02310201, -0.0025723 , -0.03468137],
#        [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,  0.0082067 ,
#          0.02803427,  0.00564752, -0.02310201, -0.0025723 , -0.03468137],
#        [-0.04710129,  0.03620065, -0.0278469 , -0.04429885,  0.0082067 ,
#          0.02803427,  0.00564752, -0.02310201, -0.0025723 , -0.03468137],
#        [-0.02559054,  0.0010379 , -0.00203985, -0.00626668,  0.00358626,
#          0.035189  ,  0.04408845, -0.03850945,  0.0299433 , -0.02185397],
#        [ 0.02554836,  0.00157478,  0.01806417,  0.03977901, -0.00447597,
#          0.03202567, -0.04774572, -0.02553369, -0.01068477, -0.04256615],
#        [-0.03677461, -0.03337146,  0.01292341,  0.04561241,  0.04770649,
#         -0.01844116,  0.04075236,  0.04460216, -0.04281138,  0.00382092],
#        [-0.01407301,  0.04640453, -0.00600319, -0.01394832,  0.00753864,
#         -0.03034344, -0.00590347,  0.0126933 ,  0.04518792,  0.02605638]],
#       dtype=float32)
